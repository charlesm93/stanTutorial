# %% [markdown]
# <a href="https://colab.research.google.com/github/charlesm93/stan_tutorial/blob/main/Stan_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rm(list = ls())
gc()

set.seed(1954)
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  782439 41.8 1410295    75.4 1410295  75.4
# Vcells 1400968 10.7 8388608    64.0 2236096  17.1

# %% [markdown]
# ## Install requisite packages

# %%
install_packages <- TRUE
if (install_packages) {
  install.packages("rjson")
  install.packages("posterior")
  install.packages("bayesplot")
  install.packages("outbreak")
}
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘outbreak’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”

# %%
if (install_packages) {
  install.packages("cmdstanr", repos = c("https://mc-stan.org/r-packages/", getOption("repos")))
  library(cmdstanr)
  install_cmdstan()
}
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# ## Load packages

# %%
library(rjson)
library(bayesplot)
library(posterior)
library(ggplot2)
library(cmdstanr)

# %% [markdown]
# ## Bayesian linear regression

# %%
data <- list(N = 10,
             x = 1:10,
             y = c(12.03037, 13.86786, 16.00795, 18.29419, 20.26679, 22.38664,
                   23.95751, 25.71993, 28.09961, 30.46859))

# %%
# define starting distribution
init <- function() {
  list(sigma = rgamma(1, 1),
       beta = rnorm(1, mean = 1, sd = 1))
}

# %%
# transpile (translate Stan to C++ and then compile)
mod <- cmdstan_model("model/linear.stan")

# %%
# run sampler
n_chains <- 4
fit <- mod$sample(data = data, chains = n_chains,
                  init = init,
                  save_warmup = TRUE,
                  parallel_chains = 4)

# %%
# Examine Stan's default summaries
fit$summary()

# %%
# Construct diagnostic plots
pars <- c("beta", "sigma")
bayesplot::mcmc_trace(fit$draws(inc_warmup = TRUE),
                      n_warmup = 1000, pars = pars)
# Out:
# plot without title

# %%
bayesplot::mcmc_dens_overlay(fit$draws(), pars = pars)
# Out:
# plot without title

# %%
# Extract posterior predictive checks
yrep <- as.matrix(
  as_draws_df(fit$draws(variables = c("y_pred"))))
head(yrep)
# Out:
#      y_pred[1] y_pred[2] y_pred[3] y_pred[4] y_pred[5] y_pred[6] y_pred[7]
# [1,]  4.86806   3.62836   6.801570  7.45162  18.2068   18.4817   21.1750
# [2,]  6.32688   6.28431   8.398340 18.58740  14.8454   20.3731   21.8031
# [3,]  4.88434   8.82639   8.065650 13.50000  18.1344   22.6704   30.7875
# [4,] -4.55767   3.85820   3.453230 12.25460  19.1781   19.6220   21.4395
# [5,]  6.06417  -3.24502  -0.104017 15.52770  21.3576   17.9893   21.9110
# [6,]  4.31985  11.07970   5.441600 19.57480  13.1623   15.4626   30.3674
#      y_pred[8] y_pred[9] y_pred[10] .chain .iteration .draw
# [1,] 11.9914   24.9719   34.6554    1      1          1
# [2,] 24.9944   27.7170   38.9745    1      2          2
# [3,] 25.2860   31.1539   30.6440    1      3          3
# [4,] 22.3202   18.9741   29.1697    1      4          4
# [5,] 22.7164   27.3915   34.6654    1      5          5
# [6,] 24.2185   37.1663   33.0855    1      6          6

# %%
# We don't need the chain, iteration and draw ID, so let's remove them.
yrep <- yrep[, -(11:13)]

# Plot the posterior predictions and compare it to the real data.
bayesplot::ppc_ribbon(y = data$y, yrep = yrep, x = data$x,
                      y_draw = "point") +
  theme_bw() +
  ylab("y")
# Out:
# plot without title

# %% [markdown]
# ## SIR model

# %%
N = 763
data_sir <- list(
  cases = c(3, 8, 26, 76, 225, 298, 258, 233, 189, 128, 68, 29, 14, 4),
  N = N,
  n_days = 14,
  ts = seq(0, 14, by = 1)[-1],
  t0 = 0,

  #initial conditions
  y0 = c(S = N - 1, I = 1, R = 0)
)

# %%
# plot the data, obtained from outbreaks
theme_set(theme_bw())
ggplot(data = data.frame(x = data_sir$ts, y = data_sir$cases)) +
  geom_point(mapping = aes(x = x, y = y)) +
  labs(y = "Number of students in bed") +
  labs(x = "Days")
# Out:
# plot without title

# %%
# define starting distribution
init <- function() {
  list(beta = abs(rnorm(1, mean = 2, sd = 1)),
       gamma = abs(rnorm(1, mean = 0.4, sd = 0.5)),
       phi_inv = rexp(1, rate = 5))
}

# transpile (translate Stan to C++ and then compile)
mod <- cmdstan_model("model/sir.stan")

# %%
n_chains <- 4
fit <- mod$sample(data = data_sir,
                  chains = n_chains,
                  parallel_chains = n_chains,
                  init = init,
                  save_warmup = TRUE)

# %%
## Check the inference
fit$summary()

pars <- c("gamma", "beta", "phi")
bayesplot::mcmc_trace(fit$draws(inc_warmup = TRUE),
                      n_warmup = 1000, pars = pars)
bayesplot::mcmc_dens_overlay(fit$draws(), pars = pars)
# Out:
#    variable       mean        median      sd          mad         q5
# 1  lp__           -65.4604440 -65.0865500  1.36007036  1.06361724 -68.18709500
# 2  gamma            0.5427073   0.5412365  0.04615425  0.04216292   0.47010640
# 3  beta             1.7334880   1.7328250  0.05182030  0.04940023   1.65133600
# 4  phi_inv          0.1388627   0.1220005  0.07579771  0.06134109   0.05070218
# 5  phi              9.4593105   8.1966800  5.43619123  4.08357707   3.51504050
# 6  y[1,1]         758.6815980 758.6970000  0.20645721  0.18829020 758.33600000
# 7  y[2,1]         747.9433767 748.0900000  1.52776059  1.35213120 745.30990000
# 8  y[3,1]         714.8356595 715.7275000  7.41185506  6.44337960 701.99855000
# 9  y[4,1]         627.0851470 629.7890000 24.57354880 21.77049840 584.09490000
# 10 y[5,1]         463.8023750 466.8160000 46.75390272 43.89607950 383.22310000
# 11 y[6,1]         285.8189029 285.8515000 49.38459964 47.59887300 205.16050000
# 12 y[7,1]         166.5921887 165.0565000 36.88691119 35.17023720 109.37430000
# 13 y[8,1]         104.5881939 103.2265000 25.58344345 24.01589610  66.00982500
# 14 y[9,1]          73.9276810  72.8355000 18.92156056 17.42596149  45.92213000
# 15 y[10,1]         58.1761202  57.1503500 15.35919097 14.05334301  35.59505500
# 16 y[11,1]         49.6219221  48.6635000 13.45864234 12.35191125  29.89610500
# 17 y[12,1]         44.7501854  43.8219000 12.42507056 11.30156328  26.68706000
# 18 y[13,1]         41.8770920  40.9881000 11.85302867 10.79532951  24.74117000
# 19 y[14,1]         40.1414331  39.2764500 11.53309306 10.43906073  23.46502500
# 20 y[1,2]           3.2785918   3.2648600  0.20674795  0.18920200   2.97619300
# 21 y[2,2]          10.6351216  10.5049500  1.34471105  1.19849677   8.75017550
# 22 y[3,2]          33.0367867  32.3112500  6.04673381  5.30044326  24.83867000
# 23 y[4,2]          89.7718962  87.5341500 18.64131317 16.64485368  64.34156500
# 24 y[5,2]         180.9413526 178.6200000 31.18505860 29.29765860 134.92460000
# 25 y[6,2]         242.0968052 242.1185000 26.36005370 24.94252110 199.41785000
# 6  758.9930000 1.0013945 2550.715 2036.780
# 7  750.1221000 1.0015666 2716.640 2254.869
# 8  724.9798500 1.0015018 2798.255 2280.591
# 9  661.0193000 1.0020433 2854.619 2126.340
# 10 532.8111500 1.0021392 2903.570 2173.316
# 11 365.2210500 1.0025277 2940.791 2122.993
# 12 227.8321000 1.0023885 2983.648 2065.896
# 13 147.3794500 1.0021963 3031.625 2408.232
# 14 106.1530000 1.0018828 3071.912 2294.292
# 15  84.2049000 1.0017103 3100.548 2138.125
# 16  72.9104500 1.0013662 3110.677 2082.916
# 17  66.6912000 1.0009235 3111.026 2050.932
# 18  62.8731200 1.0008201 3102.316 2184.168
# 19  60.5067950 1.0007345 3098.595 2244.504
# 20   3.6343620 1.0024276 2939.534 2138.748
# 21  12.9782650 1.0025169 2943.171 2138.748
# 22  43.6438900 1.0025755 2949.242 2113.105
# 23 122.6010000 1.0025045 2965.514 2163.402
# 24 235.0901500 1.0025615 3013.237 2169.880
# 25 283.9578000 1.0018008 3154.161 2244.445
# 26 259.9072500 0.9999363 2984.056 2113.710
# 27 207.5514500 1.0009470 2476.621 2068.769
# 28 152.0496000 1.0025260 2373.978 1834.362
# 29 106.3123500 1.0027578 2356.979 1730.548
# 30  72.1332600 1.0023949 2360.734 1746.638
# ⋮  ⋮           ⋮         ⋮        ⋮
# 34   1.161912  1.0000119 2534.864 2169.294
# 35   4.987133  1.0035837 2273.839 1708.755
# 36  17.886000  1.0017801 2345.599 1795.298
# 37  57.058850  1.0012246 2462.743 1911.074
# 38 147.030600  1.0012531 2538.374 2083.146
# 39 279.834700  1.0011936 2564.896 2081.506
# 40 412.676550  1.0013061 2561.987 2058.304
# 41 518.154050  1.0014647 2551.442 2033.262
# 42 592.931400  1.0016364 2553.596 2015.673
# 43 643.324150  1.0014920 2588.581 2005.596
# 44 676.872600  1.0014705 2653.642 2055.735
# 45 698.522000  1.0018153 2778.718 2222.375
# 46 712.891750  1.0017702 2950.793 2287.666
# 47 722.599450  1.0014150 3024.165 2217.635
# 48   3.677342  1.0011023 3086.354 2430.872
# 49   2.127173  1.0004954 2907.488 2154.618
# 50   7.000000  1.0008233 4212.318 3821.400
# 51  20.000000  1.0002917 3785.622 3866.973
# 52  59.000000  1.0010814 3336.356 3519.348
# 53 161.050000  1.0007883 3631.753 3544.754
# 54 315.000000  0.9996494 3509.311 3839.715
# 55 410.000000  1.0008480 4043.790 3683.551
# 56 395.050000  1.0001901 3793.969 3637.260
# 57 301.000000  0.9996683 4207.610 3761.804
# 58 215.000000  1.0000072 4098.620 3897.976
# 59 151.000000  1.0006209 3294.047 3670.488
# 60 100.000000  1.0015821 3624.387 3687.137
# 61  66.000000  1.0004436 3444.675 3913.693
# 62  44.000000  1.0008245 3327.811 3539.002
# 63  30.000000  1.0004779 3604.090 3252.926
# plot without title
# plot without title

# %%
# Extract posterior predictive checks
pred_cases <- as.matrix(
  as_draws_df(fit$draws(variables = c("pred_cases"))))[, -(15:17)]

bayesplot::ppc_ribbon(y = data_sir$cases, yrep = pred_cases,
                      x = data_sir$ts, y_draw = "point") +
  theme_bw() +
  ylab("cases") + xlab("days")
# Out:
# plot without title
